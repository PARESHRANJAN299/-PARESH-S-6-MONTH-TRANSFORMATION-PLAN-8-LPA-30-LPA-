-- %% [markdown]
-- Fetch every column and row from the customers table
-- customers
-- ▶
-- 2
-- Show only product_name and unit_price from products
-- products
-- ▶
-- 3
-- List all unique segments that exist in customers
-- customers
-- ▶
-- 4
-- Show order_id, amount, and status from orders — limit to 10 rows
-- orders
-- ▶
-- 5
-- Display employee name, department, and salary — give salary a friendly alias

-- %% [markdown]
-- Fetch every column and row from the customers table
-- customers

-- %%
select * from workspace.unilever_db.customers
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
--  2 Show only product_name and unit_price from products products

-- %%
select product_name, unit_price from workspace.unilever_db.products
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- 3 List all unique segments that exist in customers customers

-- %%
select distinct(*) from workspace.unilever_db.customers
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- 4 Show order_id, amount, and status from orders — limit to 10 rows orders

-- %%
select order_id, amount, status
from workspace.unilever_db.orders
limit(10)
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %% [markdown]
-- 5 Display employee name, department, and salary — give salary a friendly alias

-- %% [markdown]
-- this columns not availabled yet in the table. so i took diffent table.

-- %%
select customer_name, segment, customer_id, city, joined_date as joined

from workspace.unilever_db.customers
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
select * from unilever_db.products
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...
